# %% [markdown]
# # Test 3, Question 46
# > **Hint:** In Databricks, import code for all questions via this URL:
# >
# > https://github.com/flrs/spark_practice_tests_code/raw/main/spark_practice_tests_code.dbc

# %%
# %run ./create_transactionsDf
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Answer 1 (incorrect)

# %%
transactionsDf.summary()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: DataFrame[summary: string, transactionId: string, predError: string, value: string, storeId: string, productId: string, f: string]</div>

# %% [markdown]
# ## Answer 2 (incorrect)

# %%
transactionsDf.agg("count", "mean", "stddev", "25%", "50%", "75%", "min")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AssertionError</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-349681518324936&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>transactionsDf<span class="ansi-blue-fg">.</span>agg<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;count&#34;</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#34;mean&#34;</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#34;stddev&#34;</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#34;25%&#34;</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#34;50%&#34;</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#34;75%&#34;</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#34;min&#34;</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/dataframe.py</span> in <span class="ansi-cyan-fg">agg</span><span class="ansi-blue-fg">(self, *exprs)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1837</span>         <span class="ansi-blue-fg">[</span>Row<span class="ansi-blue-fg">(</span>min<span class="ansi-blue-fg">(</span>age<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">=</span><span class="ansi-cyan-fg">2</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">]</span>
# <span class="ansi-green-intense-fg ansi-bold">   1838</span>         &#34;&#34;&#34;
# <span class="ansi-green-fg">-&gt; 1839</span><span class="ansi-red-fg">         </span><span class="ansi-green-fg">return</span> self<span class="ansi-blue-fg">.</span>groupBy<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>agg<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">*</span>exprs<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1840</span>
# <span class="ansi-green-intense-fg ansi-bold">   1841</span>     <span class="ansi-blue-fg">@</span>since<span class="ansi-blue-fg">(</span><span class="ansi-cyan-fg">2.0</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/group.py</span> in <span class="ansi-cyan-fg">agg</span><span class="ansi-blue-fg">(self, *exprs)</span>
# <span class="ansi-green-intense-fg ansi-bold">    115</span>         <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    116</span>             <span class="ansi-red-fg"># Columns</span>
# <span class="ansi-green-fg">--&gt; 117</span><span class="ansi-red-fg">             </span><span class="ansi-green-fg">assert</span> all<span class="ansi-blue-fg">(</span>isinstance<span class="ansi-blue-fg">(</span>c<span class="ansi-blue-fg">,</span> Column<span class="ansi-blue-fg">)</span> <span class="ansi-green-fg">for</span> c <span class="ansi-green-fg">in</span> exprs<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#34;all exprs should be Column&#34;</span>
# <span class="ansi-green-intense-fg ansi-bold">    118</span>             jdf = self._jgd.agg(exprs[0]._jc,
# <span class="ansi-green-intense-fg ansi-bold">    119</span>                                 _to_seq(self.sql_ctx._sc, [c._jc for c in exprs[1:]]))
#
# <span class="ansi-red-fg">AssertionError</span>: all exprs should be Column</div>

# %% [markdown]
# ## Answer 3 (incorrect)

# %%
transactionsDf.summary("count", "mean", "stddev", "25%", "50%", "75%", "max").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+------------------+---------+------------------+------------------+------------------+----+
# summary|     transactionId|predError|             value|           storeId|         productId|   f|
# +-------+------------------+---------+------------------+------------------+------------------+----+
#   count|                 6|        4|                 3|                 5|                 6|   0|
#    mean|               3.5|     3.75| 4.333333333333333|              16.0|               2.0|null|
#  stddev|1.8708286933869707|      1.5|2.5166114784235836|12.328828005937952|0.6324555320336759|null|
#     25%|                 2|        3|                 2|                 3|                 2|null|
#     50%|                 3|        3|                 4|                25|                 2|null|
#     75%|                 5|        3|                 7|                25|                 2|null|
#     max|                 6|        6|                 7|                25|                 3|null|
# +-------+------------------+---------+------------------+------------------+------------------+----+
#
# </div>

# %% [markdown]
# ## Answer 4 (incorrect)

# %%
transactionsDf.agg("count", "mean", "stddev", "25%", "50%", "75%", "min").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AssertionError</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-349681518324934&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>transactionsDf<span class="ansi-blue-fg">.</span>agg<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;count&#34;</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#34;mean&#34;</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#34;stddev&#34;</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#34;25%&#34;</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#34;50%&#34;</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#34;75%&#34;</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#34;min&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>show<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/dataframe.py</span> in <span class="ansi-cyan-fg">agg</span><span class="ansi-blue-fg">(self, *exprs)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1837</span>         <span class="ansi-blue-fg">[</span>Row<span class="ansi-blue-fg">(</span>min<span class="ansi-blue-fg">(</span>age<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">=</span><span class="ansi-cyan-fg">2</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">]</span>
# <span class="ansi-green-intense-fg ansi-bold">   1838</span>         &#34;&#34;&#34;
# <span class="ansi-green-fg">-&gt; 1839</span><span class="ansi-red-fg">         </span><span class="ansi-green-fg">return</span> self<span class="ansi-blue-fg">.</span>groupBy<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>agg<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">*</span>exprs<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1840</span>
# <span class="ansi-green-intense-fg ansi-bold">   1841</span>     <span class="ansi-blue-fg">@</span>since<span class="ansi-blue-fg">(</span><span class="ansi-cyan-fg">2.0</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/group.py</span> in <span class="ansi-cyan-fg">agg</span><span class="ansi-blue-fg">(self, *exprs)</span>
# <span class="ansi-green-intense-fg ansi-bold">    115</span>         <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    116</span>             <span class="ansi-red-fg"># Columns</span>
# <span class="ansi-green-fg">--&gt; 117</span><span class="ansi-red-fg">             </span><span class="ansi-green-fg">assert</span> all<span class="ansi-blue-fg">(</span>isinstance<span class="ansi-blue-fg">(</span>c<span class="ansi-blue-fg">,</span> Column<span class="ansi-blue-fg">)</span> <span class="ansi-green-fg">for</span> c <span class="ansi-green-fg">in</span> exprs<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#34;all exprs should be Column&#34;</span>
# <span class="ansi-green-intense-fg ansi-bold">    118</span>             jdf = self._jgd.agg(exprs[0]._jc,
# <span class="ansi-green-intense-fg ansi-bold">    119</span>                                 _to_seq(self.sql_ctx._sc, [c._jc for c in exprs[1:]]))
#
# <span class="ansi-red-fg">AssertionError</span>: all exprs should be Column</div>

# %% [markdown]
# ## Answer 5 (correct)

# %%
transactionsDf.summary().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+------------------+---------+------------------+------------------+------------------+----+
# summary|     transactionId|predError|             value|           storeId|         productId|   f|
# +-------+------------------+---------+------------------+------------------+------------------+----+
#   count|                 6|        4|                 3|                 5|                 6|   0|
#    mean|               3.5|     3.75| 4.333333333333333|              16.0|               2.0|null|
#  stddev|1.8708286933869707|      1.5|2.5166114784235836|12.328828005937952|0.6324555320336759|null|
#     min|                 1|        3|                 2|                 2|                 1|null|
#     25%|                 2|        3|                 2|                 3|                 2|null|
#     50%|                 3|        3|                 4|                25|                 2|null|
#     75%|                 5|        3|                 7|                25|                 2|null|
#     max|                 6|        6|                 7|                25|                 3|null|
# +-------+------------------+---------+------------------+------------------+------------------+----+
#
# </div>
