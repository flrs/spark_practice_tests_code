# %% [markdown]
# # Test 3, Question 18
# > **Hint:** In Databricks, import code for all questions via this URL:
# >
# > https://github.com/flrs/spark_practice_tests_code/raw/main/spark_practice_tests_code.dbc

# %%
# %run ./create_transactionsDf

# %%
yesterdayTransactionsDf = transactionsDf
todayTransactionsDf = transactionsDf.limit(3)
todayTransactionsDf = todayTransactionsDf.withColumnRenamed('transactionId', 'transactionNumber')

print('todayTransactionsDf')
todayTransactionsDf.show()

print('yesterdayTransactionsDf')
yesterdayTransactionsDf.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">todayTransactionsDf
# +-----------------+---------+-----+-------+---------+----+
# transactionNumber|predError|value|storeId|productId|   f|
# +-----------------+---------+-----+-------+---------+----+
#                 1|        3|    4|     25|        1|null|
#                 2|        6|    7|      2|        2|null|
#                 3|        3| null|     25|        3|null|
# +-----------------+---------+-----+-------+---------+----+
#
# yesterdayTransactionsDf
# +-------------+---------+-----+-------+---------+----+
# transactionId|predError|value|storeId|productId|   f|
# +-------------+---------+-----+-------+---------+----+
#             1|        3|    4|     25|        1|null|
#             2|        6|    7|      2|        2|null|
#             3|        3| null|     25|        3|null|
#             4|     null| null|      3|        2|null|
#             5|     null| null|   null|        2|null|
#             6|        3|    2|     25|        2|null|
# +-------------+---------+-----+-------+---------+----+
#
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Answer 1 (incorrect)

# %%
from pyspark.sql.functions import union

union(todayTransactionsDf, yesterdayTransactionsDf).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">ImportError</span>                               Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-947490154772042&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span><span class="ansi-green-fg">from</span> pyspark<span class="ansi-blue-fg">.</span>sql<span class="ansi-blue-fg">.</span>functions <span class="ansi-green-fg">import</span> union
# <span class="ansi-green-intense-fg ansi-bold">      2</span>
# <span class="ansi-green-intense-fg ansi-bold">      3</span> union<span class="ansi-blue-fg">(</span>todayTransactionsDf<span class="ansi-blue-fg">,</span> yesterdayTransactionsDf<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>show<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">ImportError</span>: cannot import name &#39;union&#39; from &#39;pyspark.sql.functions&#39; (/databricks/spark/python/pyspark/sql/functions.py)</div>

# %% [markdown]
# ## Answer 2 (incorrect)

# %%
todayTransactionsDf.unionByName(yesterdayTransactionsDf, allowMissingColumns=True).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+---------+-----+-------+---------+----+-------------+
# transactionNumber|predError|value|storeId|productId|   f|transactionId|
# +-----------------+---------+-----+-------+---------+----+-------------+
#                 1|        3|    4|     25|        1|null|         null|
#                 2|        6|    7|      2|        2|null|         null|
#                 3|        3| null|     25|        3|null|         null|
#              null|        3|    4|     25|        1|null|            1|
#              null|        6|    7|      2|        2|null|            2|
#              null|        3| null|     25|        3|null|            3|
#              null|     null| null|      3|        2|null|            4|
#              null|     null| null|   null|        2|null|            5|
#              null|        3|    2|     25|        2|null|            6|
# +-----------------+---------+-----+-------+---------+----+-------------+
#
# </div>

# %% [markdown]
# ## Answer 3 (incorrect)

# %%
todayTransactionsDf.unionByName(yesterdayTransactionsDf).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AnalysisException</span>                         Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-947490154772038&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>todayTransactionsDf<span class="ansi-blue-fg">.</span>unionByName<span class="ansi-blue-fg">(</span>yesterdayTransactionsDf<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>show<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/dataframe.py</span> in <span class="ansi-cyan-fg">unionByName</span><span class="ansi-blue-fg">(self, other, allowMissingColumns)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1906</span>            missing columns<span class="ansi-blue-fg">.</span>
# <span class="ansi-green-intense-fg ansi-bold">   1907</span>         &#34;&#34;&#34;
# <span class="ansi-green-fg">-&gt; 1908</span><span class="ansi-red-fg">         </span><span class="ansi-green-fg">return</span> DataFrame<span class="ansi-blue-fg">(</span>self<span class="ansi-blue-fg">.</span>_jdf<span class="ansi-blue-fg">.</span>unionByName<span class="ansi-blue-fg">(</span>other<span class="ansi-blue-fg">.</span>_jdf<span class="ansi-blue-fg">,</span> allowMissingColumns<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">,</span> self<span class="ansi-blue-fg">.</span>sql_ctx<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1909</span>
# <span class="ansi-green-intense-fg ansi-bold">   1910</span>     <span class="ansi-blue-fg">@</span>since<span class="ansi-blue-fg">(</span><span class="ansi-cyan-fg">1.3</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py</span> in <span class="ansi-cyan-fg">__call__</span><span class="ansi-blue-fg">(self, *args)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1302</span>
# <span class="ansi-green-intense-fg ansi-bold">   1303</span>         answer <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>gateway_client<span class="ansi-blue-fg">.</span>send_command<span class="ansi-blue-fg">(</span>command<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">-&gt; 1304</span><span class="ansi-red-fg">         return_value = get_return_value(
# </span><span class="ansi-green-intense-fg ansi-bold">   1305</span>             answer, self.gateway_client, self.target_id, self.name)
# <span class="ansi-green-intense-fg ansi-bold">   1306</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">deco</span><span class="ansi-blue-fg">(*a, **kw)</span>
# <span class="ansi-green-intense-fg ansi-bold">    121</span>                 <span class="ansi-red-fg"># Hide where the exception came from that shows a non-Pythonic</span>
# <span class="ansi-green-intense-fg ansi-bold">    122</span>                 <span class="ansi-red-fg"># JVM exception message.</span>
# <span class="ansi-green-fg">--&gt; 123</span><span class="ansi-red-fg">                 </span><span class="ansi-green-fg">raise</span> converted <span class="ansi-green-fg">from</span> <span class="ansi-green-fg">None</span>
# <span class="ansi-green-intense-fg ansi-bold">    124</span>             <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    125</span>                 <span class="ansi-green-fg">raise</span>
#
# <span class="ansi-red-fg">AnalysisException</span>: Cannot resolve column name &#34;transactionNumber&#34; among (transactionId, predError, value, storeId, productId, f)</div>

# %% [markdown]
# ## Answer 4 (incorrect)

# %%
todayTransactionsDf.concat(yesterdayTransactionsDf).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AttributeError</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-947490154772044&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>todayTransactionsDf<span class="ansi-blue-fg">.</span>concat<span class="ansi-blue-fg">(</span>yesterdayTransactionsDf<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>show<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/dataframe.py</span> in <span class="ansi-cyan-fg">__getattr__</span><span class="ansi-blue-fg">(self, name)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1664</span>         &#34;&#34;&#34;
# <span class="ansi-green-intense-fg ansi-bold">   1665</span>         <span class="ansi-green-fg">if</span> name <span class="ansi-green-fg">not</span> <span class="ansi-green-fg">in</span> self<span class="ansi-blue-fg">.</span>columns<span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">-&gt; 1666</span><span class="ansi-red-fg">             raise AttributeError(
# </span><span class="ansi-green-intense-fg ansi-bold">   1667</span>                 &#34;&#39;%s&#39; object has no attribute &#39;%s&#39;&#34; % (self.__class__.__name__, name))
# <span class="ansi-green-intense-fg ansi-bold">   1668</span>         jc <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>_jdf<span class="ansi-blue-fg">.</span>apply<span class="ansi-blue-fg">(</span>name<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">AttributeError</span>: &#39;DataFrame&#39; object has no attribute &#39;concat&#39;</div>

# %% [markdown]
# ## Answer 5 (correct)

# %%
todayTransactionsDf.union(yesterdayTransactionsDf).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+---------+-----+-------+---------+----+
# transactionNumber|predError|value|storeId|productId|   f|
# +-----------------+---------+-----+-------+---------+----+
#                 1|        3|    4|     25|        1|null|
#                 2|        6|    7|      2|        2|null|
#                 3|        3| null|     25|        3|null|
#                 1|        3|    4|     25|        1|null|
#                 2|        6|    7|      2|        2|null|
#                 3|        3| null|     25|        3|null|
#                 4|     null| null|      3|        2|null|
#                 5|     null| null|   null|        2|null|
#                 6|        3|    2|     25|        2|null|
# +-----------------+---------+-----+-------+---------+----+
#
# </div>
