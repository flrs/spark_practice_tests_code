# %% [markdown]
# # Test 3, Question 44
# > **Hint:** In Databricks, import code for all questions via this URL:
# >
# > https://github.com/flrs/spark_practice_tests_code/raw/main/spark_practice_tests_code.dbc

# %%
# %run ./create_transactionsDf

# %%
transactionsDf.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+---------+-----+-------+---------+----+
# transactionId|predError|value|storeId|productId|   f|
# +-------------+---------+-----+-------+---------+----+
#             1|        3|    4|     25|        1|null|
#             2|        6|    7|      2|        2|null|
#             3|        3| null|     25|        3|null|
#             4|     null| null|      3|        2|null|
#             5|     null| null|   null|        2|null|
#             6|        3|    2|     25|        2|null|
# +-------------+---------+-----+-------+---------+----+
#
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
# ...

# %%
# %run ./create_itemsDf

# %%
itemsDf.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+--------------------+-------------------+
# itemId|          attributes|           supplier|
# +------+--------------------+-------------------+
#      1|[blue, winter, cozy]|Sports Company Inc.|
#      2|[red, summer, fre...|              YetiX|
#      3|[green, summer, t...|Sports Company Inc.|
# +------+--------------------+-------------------+
#
# </div>

# %% [markdown]
# ## Answer 1 (correct)

# %%
itemsDf.join(transactionsDf, itemsDf.itemId==transactionsDf.transactionId).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+--------------------+-------------------+-------------+---------+-----+-------+---------+----+
# itemId|          attributes|           supplier|transactionId|predError|value|storeId|productId|   f|
# +------+--------------------+-------------------+-------------+---------+-----+-------+---------+----+
#      1|[blue, winter, cozy]|Sports Company Inc.|            1|        3|    4|     25|        1|null|
#      2|[red, summer, fre...|              YetiX|            2|        6|    7|      2|        2|null|
#      3|[green, summer, t...|Sports Company Inc.|            3|        3| null|     25|        3|null|
# ...

# %% [markdown]
# ## Answer 2 (incorrect)

# %%
itemsDf.union(itemsDf.itemId==transactionsDf.transactionId).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">TypeError</span>                                 Traceback (most recent call last)
# ...

# %% [markdown]
# ## Answer 3 (incorrect)

# %%
# Example of what you may consider an appropriate join type.
# (The original join type is correct!)

itemsDf.join(itemsDf.itemId==transactionsDf.transactionId, how='outer').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">TypeError</span>                                 Traceback (most recent call last)
# ...

# %% [markdown]
# ## Answer 4 (incorrect)

# %%
itemsDf.merge(itemsDf.itemId==transactionsDf.transactionId).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AttributeError</span>                            Traceback (most recent call last)
# ...

# %% [markdown]
# ## Answer 5 (incorrect)

# %%
# Example of what you may consider a "well-formed" join expression.
# (The original join expression is well-formed already!)

itemsDf.join("itemsDf.itemId==transactionsDf.transactionId").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AttributeError</span>                            Traceback (most recent call last)
# ...
