# %% [markdown]
# # Test 3, Question 45
# > **Hint:** In Databricks, import code for all questions via this URL:
# >
# > https://github.com/flrs/spark_practice_tests_code/raw/main/spark_practice_tests_code.dbc

# %%
# %run ./create_transactionsDf
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
transactionsDfMonday = transactionsDf.sample(0.5, seed=42)
transactionsDfMonday.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+---------+-----+-------+---------+----+
# transactionId|predError|value|storeId|productId|   f|
# +-------------+---------+-----+-------+---------+----+
#             5|     null| null|   null|        2|null|
#             6|        3|    2|     25|        2|null|
# +-------------+---------+-----+-------+---------+----+
#
# </div>

# %%
transactionsDfTuesday = transactionsDf.sample(0.6, seed=24)
transactionsDfTuesday = transactionsDfTuesday.drop('f', 'predError')
transactionsDfTuesday = transactionsDfTuesday.select('storeId', 'transactionId', 'productId', 'value')
transactionsDfTuesday.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------------+---------+-----+
# storeId|transactionId|productId|value|
# +-------+-------------+---------+-----+
#      25|            1|        1|    4|
#       2|            2|        2|    7|
#       3|            4|        2| null|
#    null|            5|        2| null|
# +-------+-------------+---------+-----+
#
# </div>

# %% [markdown]
# ## Answer 1 (incorrect)

# %%
# resulting type is not a DataFrame

type(sc.union([transactionsDfMonday.rdd, transactionsDfTuesday.rdd]))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[26]: pyspark.rdd.RDD</div>

# %% [markdown]
# ## Answer 2 (incorrect)

# %%
sc.concat([transactionsDfMonday, transactionsDfTuesday]).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AttributeError</span>                            Traceback (most recent call last)
# ...

# %% [markdown]
# ## Answer 3 (incorrect)

# %%
transactionsDfMonday.join(transactionsDfTuesday).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+---------+-----+-------+---------+----+-------+-------------+---------+-----+
# transactionId|predError|value|storeId|productId|   f|storeId|transactionId|productId|value|
# +-------------+---------+-----+-------+---------+----+-------+-------------+---------+-----+
#             5|     null| null|   null|        2|null|     25|            1|        1|    4|
#             5|     null| null|   null|        2|null|      2|            2|        2|    7|
#             5|     null| null|   null|        2|null|      3|            4|        2| null|
# ...

# %% [markdown]
# ## Answer 4 (incorrect)

# %%
transactionsDfMonday.union(transactionsDfTuesday).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AnalysisException</span>                         Traceback (most recent call last)
# ...

# %% [markdown]
# ## Answer 5 (correct)

# %%
transactionsDfMonday.unionByName(transactionsDfTuesday, True).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+---------+-----+-------+---------+----+
# transactionId|predError|value|storeId|productId|   f|
# +-------------+---------+-----+-------+---------+----+
#             5|     null| null|   null|        2|null|
#             6|        3|    2|     25|        2|null|
#             1|     null|    4|     25|        1|null|
#             2|     null|    7|      2|        2|null|
#             4|     null| null|      3|        2|null|
#             5|     null| null|   null|        2|null|
# +-------------+---------+-----+-------+---------+----+
#
# </div>
