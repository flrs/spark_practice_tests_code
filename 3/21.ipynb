# %% [markdown]
# # Test 3, Question 21
# > **Hint:** In Databricks, import code for all questions via this URL:
# >
# > https://github.com/flrs/spark_practice_tests_code/raw/main/spark_practice_tests_code.dbc

# %%
# %run ./create_transactionsDf
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Answer 1 (incorrect)

# %%
from pyspark.sql.functions import col

transactionsDf.select('value').join(transactionsDf.select('productId'), col('value')==col('productId'), 'outer').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+---------+
# value|productId|
# +-----+---------+
#  null|     null|
#  null|     null|
#  null|     null|
#  null|        1|
#     2|        2|
#     2|        2|
#     2|        2|
#     2|        2|
#  null|        3|
#     4|     null|
#     7|     null|
# +-----+---------+
#
# </div>

# %% [markdown]
# ## Answer 2 (incorrect)

# %%
from pyspark.sql.functions import col

transactionsDf.select(col('value'), col('productId')).agg({'*': 'count'}).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+
# count(1)|
# +--------+
#        6|
# +--------+
#
# </div>

# %% [markdown]
# ## Answer 3 (incorrect)

# %%
transactionsDf.select('value', 'productId').distinct().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+---------+
# value|productId|
# +-----+---------+
#     4|        1|
#     7|        2|
#  null|        3|
#  null|        2|
#     2|        2|
# +-----+---------+
#
# </div>

# %% [markdown]
# ## Answer 4 (correct)

# %%
transactionsDf.select('value').union(transactionsDf.select('productId')).distinct().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+
# value|
# +-----+
#     4|
#     7|
#  null|
#     2|
#     1|
#     3|
# +-----+
#
# </div>

# %% [markdown]
# ## Answer 5 (incorrect)

# %%
transactionsDf.agg({'value': 'collect_set', 'productId': 'collect_set'}).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------------------+------------------+
# collect_set(productId)|collect_set(value)|
# +----------------------+------------------+
#              [1, 2, 3]|         [2, 7, 4]|
# +----------------------+------------------+
#
# </div>
