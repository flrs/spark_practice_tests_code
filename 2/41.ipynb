# %% [markdown]
# # Test 2, Question 41
# > **Hint:** In Databricks, import code for all questions via this URL:
# >
# > https://github.com/flrs/spark_practice_tests_code/raw/main/spark_practice_tests_code.dbc

# %%
# %run ./create_transactionsDf
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Answer 1 (incorrect)

# %%
transactionsDf.take(1000)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: [Row(transactionId=1, predError=3, value=4, storeId=25, productId=1, f=None),
#  Row(transactionId=2, predError=6, value=7, storeId=2, productId=2, f=None),
#  Row(transactionId=3, predError=3, value=None, storeId=25, productId=3, f=None),
#  Row(transactionId=4, predError=None, value=None, storeId=3, productId=2, f=None),
#  Row(transactionId=5, predError=None, value=None, storeId=None, productId=2, f=None),
#  Row(transactionId=6, predError=3, value=2, storeId=25, productId=2, f=None)]</div>

# %% [markdown]
# ## Answer 2 (correct)

# %%
transactionsDf.sample(True, 0.5).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+---------+-----+-------+---------+----+
# transactionId|predError|value|storeId|productId|   f|
# +-------------+---------+-----+-------+---------+----+
#             5|     null| null|   null|        2|null|
# +-------------+---------+-----+-------+---------+----+
#
# </div>

# %% [markdown]
# ## Answer 3 (incorrect)

# %%
transactionsDf.sample(False, 0.5).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+---------+-----+-------+---------+----+
# transactionId|predError|value|storeId|productId|   f|
# +-------------+---------+-----+-------+---------+----+
#             1|        3|    4|     25|        1|null|
#             3|        3| null|     25|        3|null|
#             5|     null| null|   null|        2|null|
#             6|        3|    2|     25|        2|null|
# +-------------+---------+-----+-------+---------+----+
#
# </div>

# %% [markdown]
# ## Answer 4 (incorrect)

# %%
transactionsDf.take(1000).distinct().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AttributeError</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-2469399771404088&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>transactionsDf<span class="ansi-blue-fg">.</span>take<span class="ansi-blue-fg">(</span><span class="ansi-cyan-fg">1000</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>distinct<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>show<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">AttributeError</span>: &#39;list&#39; object has no attribute &#39;distinct&#39;</div>

# %% [markdown]
# ## Answer 5 (incorrect)

# %%
transactionsDf.sample(True, 0.5, force=True).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">TypeError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-2469399771404090&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>transactionsDf<span class="ansi-blue-fg">.</span>sample<span class="ansi-blue-fg">(</span><span class="ansi-green-fg">True</span><span class="ansi-blue-fg">,</span> <span class="ansi-cyan-fg">0.5</span><span class="ansi-blue-fg">,</span> force<span class="ansi-blue-fg">=</span><span class="ansi-green-fg">True</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>show<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">TypeError</span>: sample() got an unexpected keyword argument &#39;force&#39;</div>
