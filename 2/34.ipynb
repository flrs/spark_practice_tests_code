# %% [markdown]
# # Test 2, Question 34
# > **Hint:** In Databricks, import code for all questions via this URL:
# >
# > https://github.com/flrs/spark_practice_tests_code/raw/main/spark_practice_tests_code.dbc

# %%
# %run ./create_transactionsDf
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
evaluateTestSuccess = lambda x: True
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Answer 1 (correct)

# %%
from pyspark.sql.functions import col

from pyspark.sql import types as T
evaluateTestSuccessUDF = udf(evaluateTestSuccess, T.BooleanType())
result = transactionsDf.withColumn("result", evaluateTestSuccessUDF(col("storeId")))

result.show()
result.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+---------+-----+-------+---------+----+------+
# transactionId|predError|value|storeId|productId|   f|result|
# +-------------+---------+-----+-------+---------+----+------+
#             1|        3|    4|     25|        1|null|  true|
#             2|        6|    7|      2|        2|null|  true|
#             3|        3| null|     25|        3|null|  true|
#             4|     null| null|      3|        2|null|  true|
#             5|     null| null|   null|        2|null|  true|
#             6|        3|    2|     25|        2|null|  true|
# +-------------+---------+-----+-------+---------+----+------+
#
# Out[12]: [(&#39;transactionId&#39;, &#39;int&#39;),
#  (&#39;predError&#39;, &#39;int&#39;),
#  (&#39;value&#39;, &#39;int&#39;),
#  (&#39;storeId&#39;, &#39;int&#39;),
#  (&#39;productId&#39;, &#39;int&#39;),
#  (&#39;f&#39;, &#39;int&#39;),
#  (&#39;result&#39;, &#39;boolean&#39;)]</div>

# %% [markdown]
# ## Answer 2 (incorrect)

# %%
evaluateTestSuccessUDF = udf(evaluateTestSuccess)
transactionsDf.withColumn("result", evaluateTestSuccessUDF(storeId))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-2835921636954592&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> evaluateTestSuccessUDF <span class="ansi-blue-fg">=</span> udf<span class="ansi-blue-fg">(</span>evaluateTestSuccess<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">----&gt; 2</span><span class="ansi-red-fg"> </span>transactionsDf<span class="ansi-blue-fg">.</span>withColumn<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;result&#34;</span><span class="ansi-blue-fg">,</span> evaluateTestSuccessUDF<span class="ansi-blue-fg">(</span>storeId<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">NameError</span>: name &#39;storeId&#39; is not defined</div>

# %% [markdown]
# ## Answer 3 (incorrect)

# %%
from pyspark.sql.functions import col

from pyspark.sql import types as T
evaluateTestSuccessUDF = udf(evaluateTestSuccess, T.IntegerType())
transactionsDf.withColumn("result", evaluateTestSuccess(col("storeId")))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AssertionError</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-2835921636954596&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      3</span> <span class="ansi-green-fg">from</span> pyspark<span class="ansi-blue-fg">.</span>sql <span class="ansi-green-fg">import</span> types <span class="ansi-green-fg">as</span> T
# <span class="ansi-green-intense-fg ansi-bold">      4</span> evaluateTestSuccessUDF <span class="ansi-blue-fg">=</span> udf<span class="ansi-blue-fg">(</span>evaluateTestSuccess<span class="ansi-blue-fg">,</span> T<span class="ansi-blue-fg">.</span>IntegerType<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">----&gt; 5</span><span class="ansi-red-fg"> </span>transactionsDf<span class="ansi-blue-fg">.</span>withColumn<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;result&#34;</span><span class="ansi-blue-fg">,</span> evaluateTestSuccess<span class="ansi-blue-fg">(</span>col<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;storeId&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/dataframe.py</span> in <span class="ansi-cyan-fg">withColumn</span><span class="ansi-blue-fg">(self, colName, col)</span>
# <span class="ansi-green-intense-fg ansi-bold">   2475</span>
# <span class="ansi-green-intense-fg ansi-bold">   2476</span>         &#34;&#34;&#34;
# <span class="ansi-green-fg">-&gt; 2477</span><span class="ansi-red-fg">         </span><span class="ansi-green-fg">assert</span> isinstance<span class="ansi-blue-fg">(</span>col<span class="ansi-blue-fg">,</span> Column<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#34;col should be Column&#34;</span>
# <span class="ansi-green-intense-fg ansi-bold">   2478</span>         <span class="ansi-green-fg">return</span> DataFrame<span class="ansi-blue-fg">(</span>self<span class="ansi-blue-fg">.</span>_jdf<span class="ansi-blue-fg">.</span>withColumn<span class="ansi-blue-fg">(</span>colName<span class="ansi-blue-fg">,</span> col<span class="ansi-blue-fg">.</span>_jc<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">,</span> self<span class="ansi-blue-fg">.</span>sql_ctx<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   2479</span>
#
# <span class="ansi-red-fg">AssertionError</span>: col should be Column</div>

# %% [markdown]
# ## Answer 4 (incorrect)

# %%
from pyspark.sql.functions import col

evaluateTestSuccessUDF = udf(evaluateTestSuccess)
result = transactionsDf.withColumn("result", evaluateTestSuccessUDF(col("storeId")))

result.show()
result.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+---------+-----+-------+---------+----+------+
# transactionId|predError|value|storeId|productId|   f|result|
# +-------------+---------+-----+-------+---------+----+------+
#             1|        3|    4|     25|        1|null|  true|
#             2|        6|    7|      2|        2|null|  true|
#             3|        3| null|     25|        3|null|  true|
#             4|     null| null|      3|        2|null|  true|
#             5|     null| null|   null|        2|null|  true|
#             6|        3|    2|     25|        2|null|  true|
# +-------------+---------+-----+-------+---------+----+------+
#
# Out[13]: [(&#39;transactionId&#39;, &#39;int&#39;),
#  (&#39;predError&#39;, &#39;int&#39;),
#  (&#39;value&#39;, &#39;int&#39;),
#  (&#39;storeId&#39;, &#39;int&#39;),
#  (&#39;productId&#39;, &#39;int&#39;),
#  (&#39;f&#39;, &#39;int&#39;),
#  (&#39;result&#39;, &#39;string&#39;)]</div>

# %% [markdown]
# ## Answer 5 (incorrect)

# %%
from pyspark.sql.functions import col

from pyspark.sql import types as T
evaluateTestSuccessUDF = udf(evaluateTestSuccess, T.BooleanType())
transactionsDf.withColumn("result", evaluateTestSuccess(col("storeId")))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AssertionError</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-2835921636954594&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      3</span> <span class="ansi-green-fg">from</span> pyspark<span class="ansi-blue-fg">.</span>sql <span class="ansi-green-fg">import</span> types <span class="ansi-green-fg">as</span> T
# <span class="ansi-green-intense-fg ansi-bold">      4</span> evaluateTestSuccessUDF <span class="ansi-blue-fg">=</span> udf<span class="ansi-blue-fg">(</span>evaluateTestSuccess<span class="ansi-blue-fg">,</span> T<span class="ansi-blue-fg">.</span>BooleanType<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">----&gt; 5</span><span class="ansi-red-fg"> </span>transactionsDf<span class="ansi-blue-fg">.</span>withColumn<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;result&#34;</span><span class="ansi-blue-fg">,</span> evaluateTestSuccess<span class="ansi-blue-fg">(</span>col<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;storeId&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/dataframe.py</span> in <span class="ansi-cyan-fg">withColumn</span><span class="ansi-blue-fg">(self, colName, col)</span>
# <span class="ansi-green-intense-fg ansi-bold">   2475</span>
# <span class="ansi-green-intense-fg ansi-bold">   2476</span>         &#34;&#34;&#34;
# <span class="ansi-green-fg">-&gt; 2477</span><span class="ansi-red-fg">         </span><span class="ansi-green-fg">assert</span> isinstance<span class="ansi-blue-fg">(</span>col<span class="ansi-blue-fg">,</span> Column<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#34;col should be Column&#34;</span>
# <span class="ansi-green-intense-fg ansi-bold">   2478</span>         <span class="ansi-green-fg">return</span> DataFrame<span class="ansi-blue-fg">(</span>self<span class="ansi-blue-fg">.</span>_jdf<span class="ansi-blue-fg">.</span>withColumn<span class="ansi-blue-fg">(</span>colName<span class="ansi-blue-fg">,</span> col<span class="ansi-blue-fg">.</span>_jc<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">,</span> self<span class="ansi-blue-fg">.</span>sql_ctx<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   2479</span>
#
# <span class="ansi-red-fg">AssertionError</span>: col should be Column</div>
