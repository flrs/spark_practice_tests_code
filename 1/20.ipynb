# %% [markdown]
# # Test 1, Question 20

# %%
# %run ./create_transactionsDf
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Answer 1 (incorrect)

# %%
transactionsDf.dropna("any").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+---------+-----+-------+---------+---+
# transactionId|predError|value|storeId|productId|  f|
# +-------------+---------+-----+-------+---------+---+
# +-------------+---------+-----+-------+---------+---+
#
# </div>

# %% [markdown]
# ## Answer 2 (correct)

# %%
transactionsDf.dropna(thresh=4).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+---------+-----+-------+---------+----+
# transactionId|predError|value|storeId|productId|   f|
# +-------------+---------+-----+-------+---------+----+
#             1|        3|    4|     25|        1|null|
#             2|        6|    7|      2|        2|null|
#             3|        3| null|     25|        3|null|
#             6|        3|    2|     25|        2|null|
# +-------------+---------+-----+-------+---------+----+
#
# </div>

# %% [markdown]
# ## Answer 3 (incorrect)

# %%
transactionsDf.drop.na("",2).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AttributeError</span>                            Traceback (most recent call last)
# ...

# %% [markdown]
# ## Answer 4 (incorrect)

# %%
transactionsDf.dropna(thresh=2).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+---------+-----+-------+---------+----+
# transactionId|predError|value|storeId|productId|   f|
# +-------------+---------+-----+-------+---------+----+
#             1|        3|    4|     25|        1|null|
#             2|        6|    7|      2|        2|null|
#             3|        3| null|     25|        3|null|
#             4|     null| null|      3|        2|null|
#             5|     null| null|   null|        2|null|
#             6|        3|    2|     25|        2|null|
# +-------------+---------+-----+-------+---------+----+
#
# </div>

# %% [markdown]
# ## Answer 5 (incorrect)

# %%
transactionsDf.dropna("",4).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">ValueError</span>                                Traceback (most recent call last)
# ...
