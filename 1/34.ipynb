# %% [markdown]
# # Test 1, Question 34

# %%
# %run ./create_transactionsDf
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %run ./create_itemsDf

# %% [markdown]
# ## Answer 1 (incorrect)

# %%
itemsDf.join(transactionsDf, itemsDf.itemId == transactionsDf.storeId, "right_outer").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+--------------------+-------------------+-------------+---------+-----+-------+---------+----+
# itemId|          attributes|           supplier|transactionId|predError|value|storeId|productId|   f|
# +------+--------------------+-------------------+-------------+---------+-----+-------+---------+----+
#   null|                null|               null|            5|     null| null|   null|        2|null|
#      2|[red, summer, fre...|              YetiX|            2|        6|    7|      2|        2|null|
#      3|[green, summer, t...|Sports Company Inc.|            4|     null| null|      3|        2|null|
# ...

# %% [markdown]
# ## Answer 2 (incorrect)

# %%
itemsDf.join(transactionsDf, itemsDf.itemId == transactionsDf.storeId, "broadcast").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">IllegalArgumentException</span>                  Traceback (most recent call last)
# ...

# %% [markdown]
# ## Answer 3 (incorrect)

# %%
itemsDf.merge(transactionsDf, "itemsDf.itemId == transactionsDf.storeId", "broadcast").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AttributeError</span>                            Traceback (most recent call last)
# ...

# %% [markdown]
# ## Answer 4 (correct)

# %%
from pyspark.sql.functions import broadcast

itemsDf.join(broadcast(transactionsDf), itemsDf.itemId == transactionsDf.storeId).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+--------------------+-------------------+-------------+---------+-----+-------+---------+----+
# itemId|          attributes|           supplier|transactionId|predError|value|storeId|productId|   f|
# +------+--------------------+-------------------+-------------+---------+-----+-------+---------+----+
#      2|[red, summer, fre...|              YetiX|            2|        6|    7|      2|        2|null|
#      3|[green, summer, t...|Sports Company Inc.|            4|     null| null|      3|        2|null|
# +------+--------------------+-------------------+-------------+---------+-----+-------+---------+----+
#
# </div>

# %% [markdown]
# ## Answer 5 (incorrect)

# %%
itemsDf.join(transactionsDf, broadcast(itemsDf.itemId == transactionsDf.storeId)).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">TypeError</span>                                 Traceback (most recent call last)
# ...
