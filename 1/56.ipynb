# %% [markdown]
# # Test 1, Question 56
# > **Hint:** In Databricks, import code for all questions via this URL:
# >
# > https://github.com/flrs/spark_practice_tests_code/raw/main/spark_practice_tests_code.dbc

# %%
# %run ./create_itemsDf2

# %% [markdown]
# ## Answer 1 (correct)

# %%
itemsDf.createOrReplaceTempView("itemsDf")
spark.sql("SELECT supplier, explode(attributes) FROM itemsDf").show()
# Out:
# +-------------------+-------+
# |           supplier|    col|
# +-------------------+-------+
# |Sports Company Inc.|   blue|
# |Sports Company Inc.| winter|
# |Sports Company Inc.|   cozy|
# |              YetiX|    red|
# |              YetiX| summer|
# |              YetiX|  fresh|
# |              YetiX|cooling|
# |Sports Company Inc.|  green|
# |Sports Company Inc.| summer|
# |Sports Company Inc.| travel|
# +-------------------+-------+

# %% [markdown]
# ## Answer 2 (incorrect)

# %%
itemsDf.createOrReplaceView("itemsDf")
spark.sql("SELECT supplier, explode(attributes) FROM itemsDf").show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <command-2667665041566815> in <module>
# ----> 1 itemsDf.createOrReplaceView("itemsDf")
#       2 spark.sql("SELECT supplier, explode(attributes) FROM itemsDf").show()
#
# /databricks/spark/python/pyspark/sql/dataframe.py in __getattr__(self, name)
#    1664         """
#    1665         if name not in self.columns:
# -> 1666             raise AttributeError(
#    1667                 "'%s' object has no attribute '%s'" % (self.__class__.__name__, name))
#    1668         jc = self._jdf.apply(name)
#
# AttributeError: 'DataFrame' object has no attribute 'createOrReplaceView'

# %% [markdown]
# ## Answer 3 (incorrect)

# %%
spark.sql("SELECT 'supplier', explode('Attributes') FROM itemsDf")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <command-2667665041566817> in <module>
# ----> 1 spark.sql("SELECT 'supplier', explode('Attributes') FROM itemsDf")
#
# /databricks/spark/python/pyspark/sql/session.py in sql(self, sqlQuery)
#     775         [Row(f1=1, f2='row1'), Row(f1=2, f2='row2'), Row(f1=3, f2='row3')]
#     776         """
# --> 777         return DataFrame(self._jsparkSession.sql(sqlQuery), self._wrapped)
#     778
#     779     def table(self, tableName):
#
# /databricks/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# /databricks/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
# ...

# %% [markdown]
# ## Answer 4 (incorrect)

# %%
itemsDf.createOrReplaceTempView("itemsDf")
spark.sql("SELECT 'supplier', explode('Attributes') FROM itemsDf").show()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <command-2667665041566819> in <module>
#       1 itemsDf.createOrReplaceTempView("itemsDf")
# ----> 2 spark.sql("SELECT 'supplier', explode('Attributes') FROM itemsDf").show()
#
# /databricks/spark/python/pyspark/sql/session.py in sql(self, sqlQuery)
#     775         [Row(f1=1, f2='row1'), Row(f1=2, f2='row2'), Row(f1=3, f2='row3')]
#     776         """
# --> 777         return DataFrame(self._jsparkSession.sql(sqlQuery), self._wrapped)
#     778
#     779     def table(self, tableName):
#
# /databricks/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# ...

# %% [markdown]
# ## Answer 5 (incorrect)

# %%
itemsDf.createOrReplaceView("itemsDf")
spark.sql("SELECT 'supplier', explode('Attributes') FROM itemsDf").show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <command-2667665041566821> in <module>
# ----> 1 itemsDf.createOrReplaceView("itemsDf")
#       2 spark.sql("SELECT 'supplier', explode('Attributes') FROM itemsDf").show()
#
# /databricks/spark/python/pyspark/sql/dataframe.py in __getattr__(self, name)
#    1664         """
#    1665         if name not in self.columns:
# -> 1666             raise AttributeError(
#    1667                 "'%s' object has no attribute '%s'" % (self.__class__.__name__, name))
#    1668         jc = self._jdf.apply(name)
#
# AttributeError: 'DataFrame' object has no attribute 'createOrReplaceView'
