# %% [markdown]
# # Test 1, Question 47
# > **Hint:** In Databricks, import code for all questions via this URL:
# >
# > https://github.com/flrs/spark_practice_tests_code/raw/main/spark_practice_tests_code.dbc

# %%
# %run ./create_itemsDf2

# %%
from pyspark.sql.functions import split

itemsDf = itemsDf.withColumn("itemNameElements", split("itemName"," "))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Answer 1 (incorrect)

# %%
from pyspark.sql.functions import count, col

itemsDf.select(count(col("itemNameElements"))>3).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------------------+
# (count(itemNameElements) &gt; 3)|
# +-----------------------------+
#                         false|
# +-----------------------------+
#
# </div>

# %% [markdown]
# ## Answer 2 (incorrect)

# %%
from pyspark.sql.functions import count

itemsDf.filter(count(itemNameElements)>=3).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-1768782843157450&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> <span class="ansi-green-fg">from</span> pyspark<span class="ansi-blue-fg">.</span>sql<span class="ansi-blue-fg">.</span>functions <span class="ansi-green-fg">import</span> count
# <span class="ansi-green-intense-fg ansi-bold">      2</span>
# <span class="ansi-green-fg">----&gt; 3</span><span class="ansi-red-fg"> </span>itemsDf<span class="ansi-blue-fg">.</span>filter<span class="ansi-blue-fg">(</span>count<span class="ansi-blue-fg">(</span>itemNameElements<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">&gt;=</span><span class="ansi-cyan-fg">3</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>show<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">NameError</span>: name &#39;itemNameElements&#39; is not defined</div>

# %% [markdown]
# ## Answer 3 (incorrect)

# %%
from pyspark.sql.functions import count

itemsDf.select(count("itemNameElements")>3).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------------------+
# (count(itemNameElements) &gt; 3)|
# +-----------------------------+
#                         false|
# +-----------------------------+
#
# </div>

# %% [markdown]
# ## Answer 4 (correct)

# %%
from pyspark.sql.functions import size

itemsDf.filter(size("itemNameElements")>=3).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+--------------------+--------------------+-------------------+--------------------+
# itemId|            itemName|          attributes|           supplier|    itemNameElements|
# +------+--------------------+--------------------+-------------------+--------------------+
#      1|Thick Coat for Wa...|[blue, winter, cozy]|Sports Company Inc.|[Thick, Coat, for...|
#      2|Elegant Outdoors ...|[red, summer, fre...|              YetiX|[Elegant, Outdoor...|
# +------+--------------------+--------------------+-------------------+--------------------+
#
# </div>

# %% [markdown]
# ## Answer 5 (incorrect)

# %%
from pyspark.sql.functions import size

itemsDf.select(size("itemNameElements")>3).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------------------------+
# (size(itemNameElements) &gt; 3)|
# +----------------------------+
#                         true|
#                         true|
#                        false|
# +----------------------------+
#
# </div>
